# %%
# load npz 
import numpy as np
import json

root = "/workspace/data/annotation"
full_path = root + "/full.json"
mini_path = root + "/mini.json"

full_data = json.load(open(full_path, 'r'))
mini_data = json.load(open(mini_path, 'r'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 full_path = root + "/full.json"
#       7 mini_path = root + "/mini.json"
# ----> 9 full_data = json.load(open(full_path, 'r'))
#      10 mini_data = json.load(open(mini_path, 'r'))
#
# File /opt/conda/envs/multiview-video-cls/lib/python3.11/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/data/annotation/full.json'

# %%
import json
from collections import defaultdict

def organize_labels(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    summary = defaultdict(lambda: {"count": 0, "total_duration": 0})
    organized_results = []

    for entry in data:
        video_info = {
            "video_path": entry.get("video"),
            "annotation_id": entry.get("annotation_id"),
            "labels": []
        }
        
        # 遍历视频中的所有标注
        labels_list = entry.get("videoLabels", [])
        for label_item in labels_list:
            # 获取标签名称（通常列表里只有一个元素）
            label_names = label_item.get("timelinelabels", [])
            ranges = label_item.get("ranges", [])
            
            for r in ranges:
                start = r.get("start")
                end = r.get("end")
                duration = end - start
                
                for name in label_names:
                    # 添加到该视频的整理列表中
                    video_info["labels"].append({
                        "label": name,
                        "start": start,
                        "end": end,
                        "duration": duration
                    })
                    
                    # 更新全局统计信息
                    summary[name]["count"] += 1
                    summary[name]["total_duration"] += duration
        
        # 按开始时间排序
        video_info["labels"].sort(key=lambda x: x['start'])
        organized_results.append(video_info)

    return organized_results, summary

# --- 执行整理 ---
file_name = '/workspace/data/annotation/mini.json'  # 请确保文件名正确
results, stats = organize_labels(file_name)

# --- 打印整理后的结果 ---
print("=== 标签统计摘要 ===")
print(f"{'标签':<15} | {'出现次数':<10} | {'总持续时间'}")
print("-" * 45)
for label, info in stats.items():
    print(f"{label:<15} | {info['count']:<10} | {info['total_duration']}")

print("\n=== 视频详细标注明细 (前5条) ===")
for vid in results[:1]:  # 示例打印第一个视频
    print(f"\n视频文件: {vid['video_path']}")
    for l in vid['labels'][:10]:  # 示例打印前10个标签
        print(f"  [{l['start']:>5} - {l['end']:>5}] 动作: {l['label']:<10} (时长: {l['duration']})")
    print("  ...")
# Out:
# === 标签统计摘要 ===
# 标签              | 出现次数       | 总持续时间
# ---------------------------------------------
# left            | 3219       | 151533
# right           | 2439       | 168421
# down            | 4454       | 150484
# up              | 737        | 31386
# right_up        | 64         | 3365
# right_down      | 90         | 3528
# left_down       | 423        | 15604
# left_up         | 226        | 13561
#
# === 视频详细标注明细 (前5条) ===
#
# 视频文件: /data/local-files/?d=mydata/drive_data/person_01_day_high_h265.mp4
#   [  362 -   384] 动作: left       (时长: 22)
#   [  384 -   456] 动作: right      (时长: 72)
#   [  488 -   520] 动作: down       (时长: 32)
#   [  579 -   622] 动作: down       (时长: 43)
#   [  639 -   663] 动作: right      (时长: 24)
#   [  665 -   694] 动作: down       (时长: 29)
#   [  746 -   782] 动作: down       (时长: 36)
#   [  795 -   846] 动作: down       (时长: 51)
#   [  870 -   919] 动作: down       (时长: 49)
#   [  953 -   993] 动作: down       (时长: 40)
#   ...

# %%
# --- 按视频合并不同标注者的结果 ---
import json
import os

def merge_labels_by_video(input_json, output_dir="merged_videos"):
    # 1. 创建输出目录
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 2. 读取原始数据
    with open(input_json, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 3. 使用字典按视频名归组
    # 数据结构: { "视频名": [标注者A的数据, 标注者B的数据, ...] }
    video_groups = defaultdict(list)

    for entry in data:
        # 提取视频文件名
        raw_path = entry.get("video", "unknown")
        video_filename = raw_path.split('/')[-1] if '/' in raw_path else os.path.basename(raw_path)
        video_groups[video_filename].append(entry)

    # 4. 写入文件
    for video_name, annotations in video_groups.items():
        # 构建保存文件名（例如：person_01_day_high_h265.json）
        base_name = os.path.splitext(video_name)[0]
        output_path = os.path.join(output_dir, f"{base_name}.json")
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # 构造最终的 JSON 结构
        # 包含视频名和对应的所有标注记录
        final_data = {
            "video_file": video_name,
            "total_annotators": len(annotations),
            "annotations": annotations  # 这里包含了不同 annotation_id 的完整内容
        }

        with open(output_path, 'w', encoding='utf-8') as out_f:
            json.dump(final_data, out_f, indent=4, ensure_ascii=False)
        
        print(f"成功合并: {video_name} (共有 {len(annotations)} 个人的标注结果)")
        print(f"保存路径: {output_path}")

# 执行
merge_labels_by_video('/workspace/data/annotation/mini.json', output_dir="/workspace/data/label")
# Out:
# 成功合并: person_01_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_01_day_high_h265.json
# 成功合并: person_01_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_01_day_low_h265.json
# 成功合并: person_01_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_01_night_high_h265.json
# 成功合并: person_01_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_01_night_low_h265.json
# 成功合并: person_02_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_02_day_high_h265.json
# 成功合并: person_02_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_02_day_low_h265.json
# 成功合并: person_02_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_02_night_high_h265.json
# 成功合并: person_02_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_02_night_low_h265.json
# 成功合并: person_03_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_03_day_high_h265.json
# 成功合并: person_03_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_03_day_low_h265.json
# 成功合并: person_03_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_03_night_high_h265.json
# 成功合并: person_03_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_03_night_low_h265.json
# 成功合并: person_04_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_04_day_high_h265.json
# 成功合并: person_04_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_04_day_low_h265.json
# 成功合并: person_04_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_04_night_high_h265.json
# 成功合并: person_04_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_04_night_low_h265.json
# 成功合并: person_05_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_05_day_high_h265.json
# 成功合并: person_05_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_05_day_low_h265.json
# 成功合并: person_05_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_05_night_high_h265.json
# 成功合并: person_05_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_05_night_low_h265.json
# 成功合并: person_06_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_06_day_high_h265.json
# 成功合并: person_06_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_06_day_low_h265.json
# 成功合并: person_06_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_06_night_high_h265.json
# 成功合并: person_06_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_06_night_low_h265.json
# 成功合并: person_07_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_07_day_high_h265.json
# 成功合并: person_07_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_07_day_low_h265.json
# 成功合并: person_07_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_07_night_high_h265.json
# 成功合并: person_07_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_07_night_low_h265.json
# 成功合并: person_08_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_08_day_high_h265.json
# 成功合并: person_08_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_08_day_low_h265.json
# 成功合并: person_08_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_08_night_high_h265.json
# 成功合并: person_08_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_08_night_low_h265.json
# 成功合并: person_09_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_09_day_high_h265.json
# 成功合并: person_09_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_09_day_low_h265.json
# 成功合并: person_09_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_09_night_high_h265.json
# 成功合并: person_09_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_09_night_low_h265.json
# 成功合并: person_10_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_10_day_high_h265.json
# 成功合并: person_10_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_10_day_low_h265.json
# 成功合并: person_10_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_10_night_high_h265.json
# 成功合并: person_10_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_10_night_low_h265.json
# 成功合并: person_11_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_11_day_high_h265.json
# 成功合并: person_11_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_11_day_low_h265.json
# 成功合并: person_11_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_11_night_high_h265.json
# 成功合并: person_11_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_11_night_low_h265.json
# 成功合并: person_12_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_12_day_high_h265.json
# 成功合并: person_12_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_12_day_low_h265.json
# 成功合并: person_12_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_12_night_high_h265.json
# 成功合并: person_12_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_12_night_low_h265.json
# 成功合并: person_13_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_13_day_high_h265.json
# 成功合并: person_13_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_13_day_low_h265.json
# 成功合并: person_13_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_13_night_high_h265.json
# 成功合并: person_13_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_13_night_low_h265.json
# 成功合并: person_14_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_14_day_high_h265.json
# 成功合并: person_14_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_14_day_low_h265.json
# 成功合并: person_14_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_14_night_high_h265.json
# 成功合并: person_14_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_14_night_low_h265.json
# 成功合并: person_15_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_15_day_high_h265.json
# 成功合并: person_15_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_15_day_low_h265.json
# 成功合并: person_15_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_15_night_high_h265.json
# 成功合并: person_15_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_15_night_low_h265.json
# 成功合并: person_16_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_16_day_high_h265.json
# 成功合并: person_16_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_16_day_low_h265.json
# 成功合并: person_16_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_16_night_high_h265.json
# 成功合并: person_16_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_16_night_low_h265.json
# 成功合并: person_17_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_17_day_high_h265.json
# 成功合并: person_17_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_17_day_low_h265.json
# 成功合并: person_17_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_17_night_high_h265.json
# 成功合并: person_17_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_17_night_low_h265.json
# 成功合并: person_18_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_18_day_high_h265.json
# 成功合并: person_18_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_18_day_low_h265.json
# 成功合并: person_18_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_18_night_high_h265.json
# 成功合并: person_18_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_18_night_low_h265.json
# 成功合并: person_19_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_19_day_high_h265.json
# 成功合并: person_19_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_19_day_low_h265.json
# 成功合并: person_19_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_19_night_high_h265.json
# 成功合并: person_19_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_19_night_low_h265.json
# 成功合并: person_20_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_20_day_high_h265.json
# 成功合并: person_20_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_20_day_low_h265.json
# 成功合并: person_20_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_20_night_high_h265.json
# 成功合并: person_20_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_20_night_low_h265.json
# 成功合并: person_21_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_21_day_high_h265.json
# 成功合并: person_21_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_21_day_low_h265.json
# 成功合并: person_21_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_21_night_high_h265.json
# 成功合并: person_21_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_21_night_low_h265.json
# 成功合并: person_24_day_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_24_day_high_h265.json
# 成功合并: person_24_day_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_24_day_low_h265.json
# 成功合并: person_24_night_high_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_24_night_high_h265.json
# 成功合并: person_24_night_low_h265.mp4 (共有 3 个人的标注结果)
# 保存路径: /workspace/data/label/person_24_night_low_h265.json

# %%
# 有些annotation只打了4个标签，有些打了8个标签。需要统计一下

#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import json
from pathlib import Path
from collections import Counter, defaultdict

def iter_labels_in_annotation(ann: dict):
    """Yield timelinelabel strings inside one annotation item."""
    for vl in ann.get("videoLabels", []) or []:
        for tl in (vl.get("timelinelabels", []) or []):
            if isinstance(tl, str) and tl.strip():
                yield tl.strip()

def scan(label_dir: Path):
    results = []
    for json_path in sorted(label_dir.rglob("*.json")):
        # robust read (utf-8 / utf-8-sig)
        try:
            text = json_path.read_text(encoding="utf-8")
            data = json.loads(text)
        except UnicodeDecodeError:
            text = json_path.read_text(encoding="utf-8-sig")
            data = json.loads(text)
        except Exception as e:
            print(f"[WARN] failed to read {json_path}: {e}")
            continue

        # file-level: annotator -> Counter(label -> count)
        per_annotator_counts: dict[str, Counter] = defaultdict(Counter)

        for ann in data.get("annotations", []) or []:
            aid = str(ann.get("annotator", "UNKNOWN"))
            for lb in iter_labels_in_annotation(ann):
                per_annotator_counts[aid][lb] += 1

        # make JSON-serializable summary
        per_annotator_summary = {}
        for aid, c in per_annotator_counts.items():
            per_annotator_summary[aid] = {
                "n_classes": len(c),
                "classes": sorted(c.keys()),
                "counts": dict(c.most_common()),   # label->count
                "n_total": int(sum(c.values())),
            }

        # union (optional)
        union_classes = sorted({lb for c in per_annotator_counts.values() for lb in c.keys()})

        results.append({
            "file": str(json_path.relative_to(label_dir.parent)),
            "annotators": sorted(per_annotator_summary.keys(), key=lambda x: (x=="UNKNOWN", x)),
            "per_annotator": per_annotator_summary,
            "union_classes": union_classes,
            "n_union_classes": len(union_classes),
        })

    return results


label_dir = Path("/workspace/data/multi_view_driver_action/label")
if not label_dir.exists():
    raise SystemExit(f"label folder not found: {label_dir}")

results = scan(label_dir)

# pretty print to console
for r in results:
    print(f"\n=== {r['file']} ===")
    for aid in r["annotators"]:
        s = r["per_annotator"][aid]
        print(f"- annotator {aid}: classes={s['n_classes']} total={s['n_total']}")
        print(f"  classes: {s['classes']}")
        print(f"  counts:  {s['counts']}")
    print(f"  union({r['n_union_classes']}): {r['union_classes']}")

out_path = "per_file_annotator_label_stats.json"
with open(out_path, 'w', encoding='utf-8') as out_f:
    json.dump(results, out_f, indent=4, ensure_ascii=False)
print(f"\n[INFO] saved summary to {out_path}")
# Out:
# === label/person_01_day_high_h265.json ===
# - annotator 3: classes=6 total=111
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 81, 'right': 11, 'left': 11, 'up': 6, 'left_down': 1, 'right_down': 1}
# - annotator 4: classes=6 total=85
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down']
#   counts:  {'down': 53, 'left_down': 13, 'right': 9, 'left': 8, 'left_up': 1, 'right_down': 1}
# - annotator 5: classes=7 total=125
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 82, 'right': 17, 'left': 15, 'up': 8, 'right_up': 1, 'right_down': 1, 'left_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_01_day_low_h265.json ===
# - annotator 3: classes=4 total=113
#   classes: ['down', 'left', 'left_down', 'right']
#   counts:  {'down': 83, 'right': 18, 'left': 11, 'left_down': 1}
# - annotator 4: classes=5 total=96
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 67, 'right': 13, 'left': 11, 'left_down': 4, 'up': 1}
# - annotator 5: classes=6 total=144
#   classes: ['down', 'left', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 91, 'right': 30, 'left': 13, 'up': 8, 'right_up': 1, 'right_down': 1}
#   union(7): ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_01_night_high_h265.json ===
# - annotator 3: classes=4 total=103
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 84, 'right': 12, 'left': 4, 'up': 3}
# - annotator 4: classes=5 total=68
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 48, 'left_down': 11, 'right': 5, 'left': 3, 'up': 1}
# - annotator 5: classes=7 total=145
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 90, 'up': 21, 'right': 21, 'left': 8, 'right_down': 2, 'left_down': 2, 'right_up': 1}
#   union(7): ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_01_night_low_h265.json ===
# - annotator 3: classes=6 total=119
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 84, 'up': 14, 'right': 11, 'left_down': 6, 'left_up': 3, 'left': 1}
# - annotator 4: classes=5 total=82
#   classes: ['down', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 56, 'left_down': 13, 'right': 9, 'up': 3, 'right_down': 1}
# - annotator 5: classes=8 total=131
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 78, 'left_down': 16, 'right': 12, 'right_up': 9, 'left_up': 5, 'left': 5, 'right_down': 3, 'up': 3}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_02_day_high_h265.json ===
# - annotator 3: classes=4 total=42
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 31, 'up': 6, 'left': 3, 'right': 2}
# - annotator 4: classes=5 total=38
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 31, 'left_down': 2, 'right': 2, 'up': 2, 'left': 1}
# - annotator 5: classes=4 total=49
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 32, 'up': 8, 'left': 5, 'right': 4}
#   union(5): ['down', 'left', 'left_down', 'right', 'up']
#
# === label/person_02_day_low_h265.json ===
# - annotator 3: classes=6 total=46
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 30, 'left_down': 6, 'left': 4, 'up': 3, 'right': 2, 'right_down': 1}
# - annotator 4: classes=6 total=48
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 34, 'left_down': 6, 'left': 4, 'right': 2, 'right_down': 1, 'up': 1}
# - annotator 5: classes=8 total=66
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 38, 'left': 8, 'right': 7, 'left_down': 5, 'left_up': 4, 'up': 2, 'right_up': 1, 'right_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_02_night_high_h265.json ===
# - annotator 3: classes=5 total=40
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 20, 'left_down': 8, 'up': 6, 'right': 4, 'left': 2}
# - annotator 4: classes=5 total=31
#   classes: ['down', 'left', 'left_down', 'right', 'right_up']
#   counts:  {'down': 26, 'right': 2, 'left': 1, 'right_up': 1, 'left_down': 1}
# - annotator 5: classes=6 total=45
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 26, 'left': 6, 'up': 5, 'right': 4, 'left_down': 3, 'left_up': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_02_night_low_h265.json ===
# - annotator 3: classes=4 total=27
#   classes: ['down', 'left_down', 'right', 'up']
#   counts:  {'down': 21, 'left_down': 3, 'up': 2, 'right': 1}
# - annotator 4: classes=3 total=25
#   classes: ['down', 'left_down', 'right']
#   counts:  {'down': 22, 'right': 2, 'left_down': 1}
# - annotator 5: classes=6 total=32
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 23, 'up': 3, 'left_down': 2, 'right': 2, 'left': 1, 'left_up': 1}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_03_day_high_h265.json ===
# - annotator 3: classes=4 total=14
#   classes: ['left', 'right', 'right_up', 'up']
#   counts:  {'left': 6, 'right': 5, 'up': 2, 'right_up': 1}
# - annotator 4: classes=2 total=12
#   classes: ['left', 'right']
#   counts:  {'right': 6, 'left': 6}
# - annotator 5: classes=2 total=14
#   classes: ['left', 'right']
#   counts:  {'right': 7, 'left': 7}
#   union(4): ['left', 'right', 'right_up', 'up']
#
# === label/person_03_day_low_h265.json ===
# - annotator 3: classes=3 total=18
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 10, 'right': 7, 'up': 1}
# - annotator 4: classes=2 total=13
#   classes: ['left', 'right']
#   counts:  {'left': 8, 'right': 5}
# - annotator 5: classes=4 total=20
#   classes: ['left', 'left_up', 'right', 'up']
#   counts:  {'left': 9, 'right': 8, 'up': 2, 'left_up': 1}
#   union(4): ['left', 'left_up', 'right', 'up']
#
# === label/person_03_night_high_h265.json ===
# - annotator 3: classes=5 total=17
#   classes: ['left', 'left_down', 'left_up', 'right', 'right_down']
#   counts:  {'left': 7, 'right': 7, 'left_down': 1, 'right_down': 1, 'left_up': 1}
# - annotator 4: classes=5 total=15
#   classes: ['left', 'left_down', 'left_up', 'right', 'right_down']
#   counts:  {'right': 6, 'left': 6, 'left_up': 1, 'left_down': 1, 'right_down': 1}
# - annotator 5: classes=4 total=22
#   classes: ['left', 'left_down', 'right', 'right_down']
#   counts:  {'left': 13, 'right': 7, 'left_down': 1, 'right_down': 1}
#   union(5): ['left', 'left_down', 'left_up', 'right', 'right_down']
#
# === label/person_03_night_low_h265.json ===
# - annotator 3: classes=3 total=14
#   classes: ['left', 'left_down', 'right']
#   counts:  {'left': 8, 'right': 5, 'left_down': 1}
# - annotator 4: classes=2 total=14
#   classes: ['left', 'right']
#   counts:  {'left': 8, 'right': 6}
# - annotator 5: classes=2 total=18
#   classes: ['left', 'right']
#   counts:  {'left': 11, 'right': 7}
#   union(3): ['left', 'left_down', 'right']
#
# === label/person_04_day_high_h265.json ===
# - annotator 3: classes=6 total=28
#   classes: ['down', 'left', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 17, 'right': 5, 'up': 2, 'left': 2, 'right_down': 1, 'right_up': 1}
# - annotator 4: classes=4 total=23
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 15, 'right': 5, 'left': 2, 'up': 1}
# - annotator 5: classes=5 total=29
#   classes: ['down', 'left', 'right', 'right_down', 'up']
#   counts:  {'down': 16, 'right': 8, 'up': 2, 'left': 2, 'right_down': 1}
#   union(6): ['down', 'left', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_04_day_low_h265.json ===
# - annotator 3: classes=8 total=70
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 26, 'right': 14, 'left': 13, 'up': 6, 'left_down': 4, 'right_down': 3, 'right_up': 2, 'left_up': 2}
# - annotator 4: classes=6 total=41
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 15, 'right': 10, 'left': 10, 'up': 4, 'right_down': 1, 'left_up': 1}
# - annotator 5: classes=8 total=67
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 25, 'right': 13, 'left': 12, 'up': 5, 'right_down': 5, 'left_down': 3, 'right_up': 2, 'left_up': 2}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_04_night_high_h265.json ===
# - annotator 3: classes=8 total=46
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 24, 'left_down': 8, 'right': 6, 'left': 2, 'right_up': 2, 'left_up': 2, 'right_down': 1, 'up': 1}
# - annotator 4: classes=5 total=30
#   classes: ['down', 'left', 'left_down', 'right', 'right_down']
#   counts:  {'down': 23, 'left': 2, 'left_down': 2, 'right': 2, 'right_down': 1}
# - annotator 5: classes=6 total=46
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_up']
#   counts:  {'down': 29, 'right': 6, 'left_down': 5, 'left': 3, 'right_up': 2, 'left_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_04_night_low_h265.json ===
# - annotator 3: classes=7 total=64
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 34, 'up': 12, 'right': 7, 'left': 6, 'right_up': 2, 'left_down': 2, 'right_down': 1}
# - annotator 4: classes=4 total=43
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 34, 'up': 3, 'right': 3, 'left': 3}
# - annotator 5: classes=5 total=64
#   classes: ['down', 'left', 'right', 'right_up', 'up']
#   counts:  {'down': 34, 'right': 12, 'up': 9, 'left': 6, 'right_up': 3}
#   union(7): ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_05_day_high_h265.json ===
# - annotator 3: classes=3 total=87
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 69, 'right': 17, 'down': 1}
# - annotator 4: classes=3 total=70
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 59, 'right': 9, 'down': 2}
# - annotator 5: classes=3 total=94
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 73, 'right': 19, 'down': 2}
#   union(3): ['down', 'left', 'right']
#
# === label/person_05_day_low_h265.json ===
# - annotator 3: classes=3 total=33
#   classes: ['left', 'right', 'right_up']
#   counts:  {'left': 22, 'right': 10, 'right_up': 1}
# - annotator 4: classes=4 total=28
#   classes: ['left', 'left_up', 'right', 'right_down']
#   counts:  {'left': 19, 'right': 7, 'left_up': 1, 'right_down': 1}
# - annotator 5: classes=4 total=37
#   classes: ['left', 'left_up', 'right', 'up']
#   counts:  {'left': 21, 'right': 14, 'left_up': 1, 'up': 1}
#   union(6): ['left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_05_night_high_h265.json ===
# - annotator 3: classes=2 total=73
#   classes: ['left', 'right']
#   counts:  {'left': 47, 'right': 26}
# - annotator 4: classes=3 total=63
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 44, 'right': 18, 'down': 1}
# - annotator 5: classes=4 total=81
#   classes: ['left', 'left_up', 'right', 'up']
#   counts:  {'left': 53, 'right': 26, 'left_up': 1, 'up': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_05_night_low_h265.json ===
# - annotator 3: classes=2 total=69
#   classes: ['left', 'right']
#   counts:  {'left': 56, 'right': 13}
# - annotator 4: classes=5 total=68
#   classes: ['down', 'left', 'left_down', 'right', 'right_down']
#   counts:  {'left': 49, 'right': 11, 'left_down': 5, 'down': 2, 'right_down': 1}
# - annotator 5: classes=3 total=78
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 61, 'right': 16, 'down': 1}
#   union(5): ['down', 'left', 'left_down', 'right', 'right_down']
#
# === label/person_06_day_high_h265.json ===
# - annotator 3: classes=5 total=35
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 15, 'right': 12, 'left_up': 3, 'up': 3, 'left': 2}
# - annotator 4: classes=6 total=33
#   classes: ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'down': 12, 'right': 9, 'left': 5, 'up': 5, 'left_up': 1, 'right_up': 1}
# - annotator 5: classes=8 total=61
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 16, 'right': 15, 'left': 9, 'left_up': 6, 'up': 6, 'right_down': 6, 'right_up': 2, 'left_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_06_day_low_h265.json ===
# - annotator 3: classes=6 total=30
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'up': 9, 'down': 7, 'right': 7, 'left': 5, 'right_down': 1, 'left_up': 1}
# - annotator 4: classes=5 total=20
#   classes: ['down', 'left', 'right', 'right_down', 'up']
#   counts:  {'down': 6, 'right': 6, 'left': 4, 'up': 3, 'right_down': 1}
# - annotator 5: classes=7 total=51
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'right': 14, 'up': 11, 'down': 11, 'left': 7, 'right_down': 5, 'left_up': 2, 'right_up': 1}
#   union(7): ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_06_night_high_h265.json ===
# - annotator 3: classes=7 total=46
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'left': 15, 'right': 13, 'up': 9, 'down': 5, 'left_up': 2, 'left_down': 1, 'right_up': 1}
# - annotator 4: classes=7 total=28
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'left': 12, 'down': 5, 'right': 5, 'up': 3, 'left_up': 1, 'right_up': 1, 'right_down': 1}
# - annotator 5: classes=7 total=75
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'left': 25, 'right': 15, 'up': 14, 'down': 10, 'left_up': 8, 'right_down': 2, 'right_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_06_night_low_h265.json ===
# - annotator 3: classes=6 total=30
#   classes: ['down', 'left', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'left': 9, 'right': 9, 'down': 5, 'up': 4, 'right_down': 2, 'right_up': 1}
# - annotator 4: classes=6 total=27
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 9, 'left': 7, 'right': 7, 'up': 2, 'right_down': 1, 'left_down': 1}
# - annotator 5: classes=7 total=65
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 20, 'right': 19, 'left': 11, 'up': 9, 'left_up': 3, 'right_down': 2, 'left_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_07_day_high_h265.json ===
# - annotator 3: classes=4 total=32
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 15, 'right': 13, 'down': 2, 'up': 2}
# - annotator 4: classes=3 total=24
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 15, 'right': 6, 'down': 3}
# - annotator 5: classes=4 total=36
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 20, 'right': 12, 'down': 2, 'up': 2}
#   union(4): ['down', 'left', 'right', 'up']
#
# === label/person_07_day_low_h265.json ===
# - annotator 3: classes=4 total=25
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 13, 'right': 9, 'up': 2, 'down': 1}
# - annotator 4: classes=5 total=21
#   classes: ['down', 'left', 'left_up', 'right', 'right_up']
#   counts:  {'left': 11, 'right': 4, 'right_up': 3, 'left_up': 2, 'down': 1}
# - annotator 5: classes=4 total=22
#   classes: ['left', 'left_up', 'right', 'up']
#   counts:  {'left': 10, 'right': 10, 'left_up': 1, 'up': 1}
#   union(6): ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_07_night_high_h265.json ===
# - annotator 3: classes=5 total=36
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 17, 'right': 13, 'up': 4, 'left_up': 1, 'down': 1}
# - annotator 4: classes=5 total=35
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 18, 'right': 11, 'left_up': 4, 'up': 1, 'down': 1}
# - annotator 5: classes=4 total=43
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 20, 'right': 13, 'left_up': 8, 'down': 2}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_07_night_low_h265.json ===
# - annotator 3: classes=3 total=26
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 13, 'right': 12, 'up': 1}
# - annotator 4: classes=4 total=26
#   classes: ['left', 'left_up', 'right', 'right_up']
#   counts:  {'left': 13, 'right': 10, 'right_up': 2, 'left_up': 1}
# - annotator 5: classes=3 total=30
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 15, 'right': 14, 'up': 1}
#   union(5): ['left', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_08_day_high_h265.json ===
# - annotator 3: classes=3 total=22
#   classes: ['down', 'left', 'right']
#   counts:  {'down': 11, 'right': 6, 'left': 5}
# - annotator 4: classes=3 total=14
#   classes: ['down', 'left', 'right']
#   counts:  {'down': 8, 'right': 5, 'left': 1}
# - annotator 5: classes=4 total=23
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'right': 10, 'down': 8, 'left': 4, 'up': 1}
#   union(4): ['down', 'left', 'right', 'up']
#
# === label/person_08_day_low_h265.json ===
# - annotator 3: classes=7 total=46
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'left': 16, 'right': 15, 'down': 10, 'left_down': 2, 'up': 1, 'left_up': 1, 'right_up': 1}
# - annotator 4: classes=6 total=27
#   classes: ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'down': 9, 'right': 9, 'left': 6, 'up': 1, 'right_up': 1, 'left_up': 1}
# - annotator 5: classes=8 total=49
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'left': 18, 'right': 15, 'down': 7, 'left_up': 3, 'left_down': 3, 'up': 1, 'right_down': 1, 'right_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_08_night_high_h265.json ===
# - annotator 3: classes=5 total=25
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'right': 8, 'left': 7, 'down': 6, 'up': 3, 'left_up': 1}
# - annotator 4: classes=4 total=17
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'right': 6, 'down': 4, 'left': 4, 'up': 3}
# - annotator 5: classes=5 total=29
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 10, 'right': 7, 'down': 6, 'up': 4, 'left_up': 2}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_08_night_low_h265.json ===
# - annotator 3: classes=4 total=15
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'right': 6, 'down': 4, 'left': 3, 'left_up': 2}
# - annotator 4: classes=4 total=15
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 7, 'right': 6, 'up': 1, 'left': 1}
# - annotator 5: classes=6 total=28
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'right': 11, 'down': 5, 'left': 5, 'left_up': 4, 'up': 2, 'right_down': 1}
#   union(6): ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_09_day_high_h265.json ===
# - annotator 3: classes=6 total=27
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'left': 10, 'left_down': 7, 'right': 4, 'down': 2, 'up': 2, 'left_up': 2}
# - annotator 4: classes=6 total=27
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 11, 'left': 9, 'right': 3, 'left_down': 2, 'up': 1, 'right_down': 1}
# - annotator 5: classes=5 total=30
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'left': 12, 'down': 8, 'up': 5, 'right': 4, 'left_down': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_09_day_low_h265.json ===
# - annotator 3: classes=5 total=31
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 11, 'right': 11, 'down': 6, 'up': 2, 'left_up': 1}
# - annotator 4: classes=4 total=32
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 12, 'left': 10, 'right': 8, 'up': 2}
# - annotator 5: classes=5 total=79
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 24, 'down': 23, 'right': 19, 'up': 12, 'left_up': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_09_night_high_h265.json ===
# - annotator 3: classes=7 total=53
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 17, 'left': 15, 'right': 10, 'up': 7, 'left_down': 2, 'right_down': 1, 'left_up': 1}
# - annotator 4: classes=4 total=35
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 16, 'left': 10, 'right': 8, 'up': 1}
# - annotator 5: classes=6 total=68
#   classes: ['down', 'left', 'left_down', 'right', 'right_up', 'up']
#   counts:  {'down': 26, 'left': 18, 'right': 11, 'up': 10, 'left_down': 2, 'right_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_09_night_low_h265.json ===
# - annotator 3: classes=5 total=33
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'up': 13, 'left': 8, 'down': 7, 'right': 4, 'left_down': 1}
# - annotator 4: classes=4 total=27
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'up': 9, 'left': 7, 'down': 7, 'right': 4}
# - annotator 5: classes=5 total=45
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 18, 'up': 11, 'left': 8, 'right': 7, 'left_down': 1}
#   union(5): ['down', 'left', 'left_down', 'right', 'up']
#
# === label/person_10_day_high_h265.json ===
# - annotator 3: classes=3 total=22
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 16, 'right': 5, 'down': 1}
# - annotator 4: classes=4 total=33
#   classes: ['down', 'left', 'left_down', 'right']
#   counts:  {'left': 19, 'right': 10, 'down': 3, 'left_down': 1}
# - annotator 5: classes=4 total=30
#   classes: ['down', 'left', 'left_down', 'right']
#   counts:  {'left': 17, 'right': 10, 'down': 2, 'left_down': 1}
#   union(4): ['down', 'left', 'left_down', 'right']
#
# === label/person_10_day_low_h265.json ===
# - annotator 3: classes=3 total=25
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 16, 'right': 7, 'down': 2}
# - annotator 4: classes=4 total=26
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 18, 'right': 5, 'down': 2, 'left_up': 1}
# - annotator 5: classes=5 total=29
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 13, 'right': 12, 'down': 2, 'up': 1, 'left_up': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_10_night_high_h265.json ===
# - annotator 3: classes=3 total=13
#   classes: ['left', 'left_down', 'right']
#   counts:  {'left': 7, 'right': 5, 'left_down': 1}
# - annotator 4: classes=5 total=25
#   classes: ['down', 'left', 'left_down', 'right', 'right_down']
#   counts:  {'left': 15, 'right': 6, 'down': 2, 'right_down': 1, 'left_down': 1}
# - annotator 5: classes=2 total=27
#   classes: ['left', 'right']
#   counts:  {'left': 14, 'right': 13}
#   union(5): ['down', 'left', 'left_down', 'right', 'right_down']
#
# === label/person_10_night_low_h265.json ===
# - annotator 3: classes=2 total=26
#   classes: ['left', 'right']
#   counts:  {'left': 17, 'right': 9}
# - annotator 4: classes=2 total=24
#   classes: ['left', 'right']
#   counts:  {'left': 18, 'right': 6}
# - annotator 5: classes=3 total=35
#   classes: ['left', 'left_up', 'right']
#   counts:  {'left': 19, 'right': 15, 'left_up': 1}
#   union(3): ['left', 'left_up', 'right']
#
# === label/person_11_day_high_h265.json ===
# - annotator 3: classes=6 total=54
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 17, 'right': 13, 'left': 13, 'up': 9, 'left_up': 1, 'left_down': 1}
# - annotator 4: classes=5 total=50
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 22, 'right': 10, 'left': 9, 'up': 7, 'left_down': 2}
# - annotator 5: classes=7 total=64
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 28, 'right': 15, 'left': 15, 'left_up': 3, 'left_down': 1, 'right_down': 1, 'up': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_11_day_low_h265.json ===
# - annotator 3: classes=7 total=65
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'down': 22, 'right': 14, 'left': 14, 'up': 9, 'left_down': 4, 'left_up': 1, 'right_up': 1}
# - annotator 4: classes=6 total=62
#   classes: ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'down': 26, 'right': 13, 'left': 13, 'up': 6, 'left_up': 3, 'right_up': 1}
# - annotator 5: classes=6 total=80
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 27, 'left': 19, 'right': 16, 'left_down': 9, 'up': 5, 'left_up': 4}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_11_night_high_h265.json ===
# - annotator 3: classes=4 total=48
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 26, 'right': 8, 'up': 7, 'left': 7}
# - annotator 4: classes=5 total=50
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 30, 'left': 8, 'right': 8, 'up': 3, 'left_up': 1}
# - annotator 5: classes=5 total=65
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 33, 'left': 14, 'right': 11, 'left_up': 5, 'up': 2}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_11_night_low_h265.json ===
# - annotator 3: classes=5 total=70
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 31, 'left': 16, 'right': 13, 'up': 5, 'left_down': 5}
# - annotator 4: classes=4 total=76
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 42, 'left': 16, 'right': 12, 'up': 6}
# - annotator 5: classes=7 total=91
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 33, 'left': 19, 'right': 17, 'left_down': 13, 'left_up': 4, 'right_down': 3, 'up': 2}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_12_day_high_h265.json ===
# - annotator 3: classes=2 total=2
#   classes: ['left', 'right']
#   counts:  {'right': 1, 'left': 1}
# - annotator 4: classes=2 total=2
#   classes: ['left', 'right']
#   counts:  {'right': 1, 'left': 1}
# - annotator 5: classes=2 total=2
#   classes: ['left', 'right']
#   counts:  {'right': 1, 'left': 1}
#   union(2): ['left', 'right']
#
# === label/person_12_day_low_h265.json ===
# - annotator 3: classes=3 total=3
#   classes: ['down', 'left', 'right']
#   counts:  {'right': 1, 'left': 1, 'down': 1}
# - annotator 4: classes=2 total=3
#   classes: ['left', 'right']
#   counts:  {'right': 2, 'left': 1}
# - annotator 5: classes=2 total=3
#   classes: ['left', 'right']
#   counts:  {'right': 2, 'left': 1}
#   union(3): ['down', 'left', 'right']
#
# === label/person_12_night_high_h265.json ===
# - annotator 3: classes=3 total=5
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 2, 'down': 2, 'right': 1}
# - annotator 4: classes=3 total=3
#   classes: ['left', 'left_down', 'right']
#   counts:  {'left': 1, 'right': 1, 'left_down': 1}
# - annotator 5: classes=3 total=4
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 2, 'right': 1, 'down': 1}
#   union(4): ['down', 'left', 'left_down', 'right']
#
# === label/person_12_night_low_h265.json ===
# - annotator 3: classes=3 total=3
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 1, 'right': 1, 'down': 1}
# - annotator 4: classes=2 total=2
#   classes: ['left', 'right']
#   counts:  {'right': 1, 'left': 1}
# - annotator 5: classes=3 total=5
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 3, 'right': 1, 'down': 1}
#   union(3): ['down', 'left', 'right']
#
# === label/person_13_day_high_h265.json ===
# - annotator 3: classes=6 total=60
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'left': 22, 'down': 15, 'right': 12, 'up': 5, 'left_down': 5, 'left_up': 1}
# - annotator 4: classes=5 total=63
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 27, 'left': 18, 'right': 11, 'up': 5, 'left_down': 2}
# - annotator 5: classes=7 total=90
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 28, 'left': 28, 'right': 17, 'up': 8, 'left_down': 6, 'left_up': 2, 'right_down': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_13_day_low_h265.json ===
# - annotator 3: classes=7 total=69
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'left_down': 27, 'left': 14, 'right': 14, 'down': 7, 'up': 5, 'right_up': 1, 'left_up': 1}
# - annotator 4: classes=6 total=64
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 33, 'left': 13, 'right': 8, 'left_down': 5, 'up': 4, 'right_down': 1}
# - annotator 5: classes=6 total=84
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 35, 'left': 17, 'right': 16, 'left_down': 11, 'right_down': 3, 'up': 2}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_13_night_high_h265.json ===
# - annotator 3: classes=6 total=72
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 24, 'left': 15, 'up': 12, 'right': 12, 'left_down': 8, 'left_up': 1}
# - annotator 4: classes=6 total=76
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 37, 'left': 14, 'up': 12, 'right': 11, 'left_down': 1, 'left_up': 1}
# - annotator 5: classes=6 total=93
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 39, 'left': 20, 'right': 18, 'left_up': 7, 'up': 6, 'left_down': 3}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_13_night_low_h265.json ===
# - annotator 3: classes=6 total=83
#   classes: ['down', 'left', 'left_down', 'right', 'right_up', 'up']
#   counts:  {'left': 25, 'down': 19, 'right': 18, 'up': 11, 'left_down': 9, 'right_up': 1}
# - annotator 4: classes=6 total=76
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 28, 'left': 21, 'right': 17, 'up': 7, 'right_down': 2, 'left_down': 1}
# - annotator 5: classes=6 total=92
#   classes: ['down', 'left', 'left_down', 'right', 'right_up', 'up']
#   counts:  {'down': 35, 'left': 25, 'right': 21, 'up': 9, 'right_up': 1, 'left_down': 1}
#   union(7): ['down', 'left', 'left_down', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_14_day_high_h265.json ===
# - annotator 3: classes=2 total=28
#   classes: ['left', 'right']
#   counts:  {'left': 21, 'right': 7}
# - annotator 4: classes=2 total=24
#   classes: ['left', 'right']
#   counts:  {'left': 17, 'right': 7}
# - annotator 5: classes=3 total=32
#   classes: ['left', 'left_down', 'right']
#   counts:  {'left': 21, 'right': 10, 'left_down': 1}
#   union(3): ['left', 'left_down', 'right']
#
# === label/person_14_day_low_h265.json ===
# - annotator 3: classes=3 total=30
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 23, 'right': 5, 'up': 2}
# - annotator 4: classes=3 total=36
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 25, 'right': 7, 'up': 4}
# - annotator 5: classes=2 total=36
#   classes: ['left', 'right']
#   counts:  {'left': 26, 'right': 10}
#   union(3): ['left', 'right', 'up']
#
# === label/person_14_night_high_h265.json ===
# - annotator 3: classes=3 total=16
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 13, 'right': 2, 'up': 1}
# - annotator 4: classes=3 total=20
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 15, 'right': 4, 'up': 1}
# - annotator 5: classes=3 total=22
#   classes: ['left', 'right', 'up']
#   counts:  {'left': 15, 'right': 5, 'up': 2}
#   union(3): ['left', 'right', 'up']
#
# === label/person_14_night_low_h265.json ===
# - annotator 3: classes=2 total=30
#   classes: ['left', 'right']
#   counts:  {'left': 24, 'right': 6}
# - annotator 4: classes=3 total=28
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 21, 'right': 6, 'down': 1}
# - annotator 5: classes=3 total=35
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 27, 'right': 6, 'down': 2}
#   union(3): ['down', 'left', 'right']
#
# === label/person_15_day_high_h265.json ===
# - annotator 3: classes=4 total=35
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 23, 'right': 10, 'left_up': 1, 'down': 1}
# - annotator 4: classes=4 total=36
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 21, 'right': 13, 'up': 1, 'down': 1}
# - annotator 5: classes=4 total=39
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 23, 'right': 14, 'up': 1, 'down': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_15_day_low_h265.json ===
# - annotator 3: classes=3 total=35
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 21, 'right': 11, 'down': 3}
# - annotator 4: classes=4 total=36
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 20, 'right': 13, 'down': 2, 'left_up': 1}
# - annotator 5: classes=4 total=38
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 19, 'right': 16, 'down': 2, 'up': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_15_night_high_h265.json ===
# - annotator 3: classes=3 total=37
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 24, 'right': 11, 'down': 2}
# - annotator 4: classes=3 total=32
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 21, 'right': 10, 'down': 1}
# - annotator 5: classes=3 total=43
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 26, 'right': 15, 'down': 2}
#   union(3): ['down', 'left', 'right']
#
# === label/person_15_night_low_h265.json ===
# - annotator 3: classes=4 total=37
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 21, 'right': 14, 'down': 1, 'left_up': 1}
# - annotator 4: classes=4 total=37
#   classes: ['left', 'left_up', 'right', 'up']
#   counts:  {'left': 23, 'right': 12, 'up': 1, 'left_up': 1}
# - annotator 5: classes=5 total=53
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 25, 'right': 23, 'up': 2, 'left_up': 2, 'down': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_16_day_high_h265.json ===
# - annotator 3: classes=6 total=80
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 51, 'right': 19, 'left': 5, 'left_down': 2, 'left_up': 2, 'up': 1}
# - annotator 4: classes=4 total=75
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 51, 'right': 16, 'left': 5, 'up': 3}
# - annotator 5: classes=6 total=83
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 52, 'right': 21, 'left': 5, 'up': 2, 'left_down': 2, 'left_up': 1}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_16_day_low_h265.json ===
# - annotator 3: classes=6 total=88
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 65, 'right': 15, 'left': 4, 'up': 2, 'left_down': 1, 'left_up': 1}
# - annotator 4: classes=4 total=89
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 66, 'right': 15, 'left': 5, 'up': 3}
# - annotator 5: classes=6 total=94
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 63, 'right': 16, 'left': 9, 'up': 3, 'left_down': 2, 'right_down': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_16_night_high_h265.json ===
# - annotator 3: classes=4 total=63
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 47, 'right': 8, 'up': 5, 'left': 3}
# - annotator 4: classes=5 total=57
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 46, 'right': 7, 'left': 2, 'up': 1, 'left_down': 1}
# - annotator 5: classes=7 total=62
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 48, 'right': 6, 'left': 3, 'up': 2, 'right_down': 1, 'left_up': 1, 'left_down': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_16_night_low_h265.json ===
# - annotator 3: classes=6 total=72
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 45, 'right': 12, 'up': 6, 'left': 6, 'left_up': 2, 'left_down': 1}
# - annotator 4: classes=5 total=68
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 48, 'right': 11, 'left': 4, 'left_up': 3, 'up': 2}
# - annotator 5: classes=6 total=71
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 46, 'right': 12, 'left': 6, 'left_up': 5, 'up': 1, 'left_down': 1}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_17_day_high_h265.json ===
# - annotator 3: classes=2 total=13
#   classes: ['left', 'right']
#   counts:  {'right': 7, 'left': 6}
# - annotator 4: classes=2 total=8
#   classes: ['left', 'right']
#   counts:  {'right': 5, 'left': 3}
# - annotator 5: classes=2 total=11
#   classes: ['left', 'right']
#   counts:  {'right': 6, 'left': 5}
#   union(2): ['left', 'right']
#
# === label/person_17_day_low_h265.json ===
# - annotator 3: classes=2 total=7
#   classes: ['left', 'right']
#   counts:  {'left': 4, 'right': 3}
# - annotator 4: classes=2 total=9
#   classes: ['left', 'right']
#   counts:  {'right': 5, 'left': 4}
# - annotator 5: classes=3 total=9
#   classes: ['left', 'right', 'right_up']
#   counts:  {'right': 5, 'left': 3, 'right_up': 1}
#   union(3): ['left', 'right', 'right_up']
#
# === label/person_17_night_high_h265.json ===
# - annotator 3: classes=2 total=8
#   classes: ['left', 'right']
#   counts:  {'right': 4, 'left': 4}
# - annotator 4: classes=3 total=10
#   classes: ['down', 'left', 'right']
#   counts:  {'right': 4, 'left': 4, 'down': 2}
# - annotator 5: classes=6 total=15
#   classes: ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#   counts:  {'left': 6, 'right': 5, 'right_up': 1, 'left_up': 1, 'down': 1, 'up': 1}
#   union(6): ['down', 'left', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_17_night_low_h265.json ===
# - annotator 3: classes=2 total=8
#   classes: ['left', 'right']
#   counts:  {'right': 5, 'left': 3}
# - annotator 4: classes=3 total=11
#   classes: ['down', 'left', 'right']
#   counts:  {'right': 6, 'left': 4, 'down': 1}
# - annotator 5: classes=2 total=10
#   classes: ['left', 'right']
#   counts:  {'right': 7, 'left': 3}
#   union(3): ['down', 'left', 'right']
#
# === label/person_18_day_high_h265.json ===
# - annotator 3: classes=4 total=36
#   classes: ['down', 'left', 'left_down', 'right']
#   counts:  {'left': 17, 'right': 16, 'left_down': 2, 'down': 1}
# - annotator 4: classes=4 total=36
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 18, 'right': 15, 'up': 2, 'down': 1}
# - annotator 5: classes=4 total=37
#   classes: ['left', 'left_up', 'right', 'right_up']
#   counts:  {'left': 17, 'right': 15, 'left_up': 3, 'right_up': 2}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_up', 'up']
#
# === label/person_18_day_low_h265.json ===
# - annotator 3: classes=3 total=19
#   classes: ['left', 'left_down', 'right']
#   counts:  {'right': 9, 'left': 8, 'left_down': 2}
# - annotator 4: classes=2 total=16
#   classes: ['left', 'right']
#   counts:  {'left': 8, 'right': 8}
# - annotator 5: classes=2 total=20
#   classes: ['left', 'right']
#   counts:  {'left': 11, 'right': 9}
#   union(3): ['left', 'left_down', 'right']
#
# === label/person_18_night_high_h265.json ===
# - annotator 3: classes=2 total=12
#   classes: ['left', 'right']
#   counts:  {'left': 8, 'right': 4}
# - annotator 4: classes=2 total=13
#   classes: ['left', 'right']
#   counts:  {'left': 9, 'right': 4}
# - annotator 5: classes=2 total=14
#   classes: ['left', 'right']
#   counts:  {'left': 10, 'right': 4}
#   union(2): ['left', 'right']
#
# === label/person_18_night_low_h265.json ===
# - annotator 3: classes=3 total=23
#   classes: ['left', 'left_down', 'right']
#   counts:  {'right': 11, 'left': 10, 'left_down': 2}
# - annotator 4: classes=3 total=26
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 13, 'right': 12, 'down': 1}
# - annotator 5: classes=3 total=26
#   classes: ['left', 'left_down', 'right']
#   counts:  {'right': 13, 'left': 12, 'left_down': 1}
#   union(4): ['down', 'left', 'left_down', 'right']
#
# === label/person_19_day_high_h265.json ===
# - annotator 3: classes=5 total=21
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'left': 8, 'right': 7, 'up': 3, 'left_down': 2, 'down': 1}
# - annotator 4: classes=5 total=18
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'right': 8, 'left': 6, 'up': 2, 'down': 1, 'left_up': 1}
# - annotator 5: classes=3 total=17
#   classes: ['left', 'left_down', 'right']
#   counts:  {'right': 8, 'left': 7, 'left_down': 2}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_19_day_low_h265.json ===
# - annotator 3: classes=4 total=10
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 3, 'left': 3, 'right': 3, 'up': 1}
# - annotator 4: classes=3 total=8
#   classes: ['down', 'left', 'right']
#   counts:  {'right': 4, 'down': 2, 'left': 2}
# - annotator 5: classes=2 total=5
#   classes: ['left', 'right']
#   counts:  {'right': 3, 'left': 2}
#   union(4): ['down', 'left', 'right', 'up']
#
# === label/person_19_night_high_h265.json ===
# - annotator 3: classes=4 total=17
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 7, 'up': 5, 'down': 3, 'right': 2}
# - annotator 4: classes=4 total=17
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 5, 'down': 5, 'right': 4, 'up': 3}
# - annotator 5: classes=3 total=8
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 4, 'right': 3, 'down': 1}
#   union(4): ['down', 'left', 'right', 'up']
#
# === label/person_19_night_low_h265.json ===
# - annotator 3: classes=4 total=17
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'left': 11, 'right': 4, 'up': 1, 'down': 1}
# - annotator 4: classes=4 total=17
#   classes: ['down', 'left', 'left_up', 'right']
#   counts:  {'left': 11, 'right': 3, 'down': 2, 'left_up': 1}
# - annotator 5: classes=3 total=17
#   classes: ['down', 'left', 'right']
#   counts:  {'left': 12, 'right': 4, 'down': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# === label/person_20_day_high_h265.json ===
# - annotator 3: classes=6 total=93
#   classes: ['down', 'left', 'left_down', 'right', 'right_down', 'up']
#   counts:  {'down': 74, 'right': 8, 'up': 4, 'left_down': 3, 'left': 3, 'right_down': 1}
# - annotator 4: classes=4 total=76
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 57, 'right': 9, 'left': 7, 'up': 3}
# - annotator 5: classes=7 total=95
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 43, 'left_down': 29, 'right': 9, 'left': 7, 'right_down': 4, 'up': 2, 'left_up': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_20_day_low_h265.json ===
# - annotator 3: classes=6 total=91
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 60, 'right': 14, 'left': 12, 'up': 3, 'left_up': 1, 'right_down': 1}
# - annotator 4: classes=4 total=64
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 39, 'right': 15, 'left': 9, 'up': 1}
# - annotator 5: classes=7 total=87
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 40, 'left': 15, 'left_down': 14, 'right': 12, 'up': 3, 'right_down': 2, 'left_up': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_20_night_high_h265.json ===
# - annotator 3: classes=5 total=94
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 64, 'left': 16, 'right': 8, 'left_down': 4, 'up': 2}
# - annotator 4: classes=5 total=62
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 35, 'left': 11, 'right': 8, 'left_down': 4, 'up': 4}
# - annotator 5: classes=8 total=93
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 41, 'left': 16, 'left_down': 13, 'right': 12, 'up': 6, 'right_up': 3, 'right_down': 1, 'left_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_20_night_low_h265.json ===
# - annotator 3: classes=5 total=82
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 56, 'right': 12, 'left': 10, 'left_down': 2, 'up': 2}
# - annotator 4: classes=5 total=69
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 47, 'left': 10, 'right': 8, 'up': 3, 'left_up': 1}
# - annotator 5: classes=8 total=80
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 32, 'left_down': 25, 'right': 10, 'left': 9, 'up': 1, 'right_up': 1, 'left_up': 1, 'right_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_21_day_high_h265.json ===
# - annotator 3: classes=5 total=82
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 37, 'right': 17, 'left': 16, 'up': 11, 'left_up': 1}
# - annotator 4: classes=6 total=79
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 38, 'left': 18, 'right': 14, 'up': 7, 'right_down': 1, 'left_up': 1}
# - annotator 5: classes=7 total=101
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 42, 'left': 23, 'right': 22, 'up': 7, 'left_up': 4, 'right_up': 2, 'right_down': 1}
#   union(7): ['down', 'left', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_21_day_low_h265.json ===
# - annotator 3: classes=5 total=57
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 24, 'up': 11, 'left': 11, 'right': 10, 'left_up': 1}
# - annotator 4: classes=6 total=54
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 23, 'right': 11, 'left': 10, 'up': 6, 'left_up': 3, 'left_down': 1}
# - annotator 5: classes=7 total=69
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 26, 'right': 15, 'left': 11, 'left_up': 8, 'up': 7, 'left_down': 1, 'right_down': 1}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_21_night_high_h265.json ===
# - annotator 3: classes=6 total=70
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'right': 22, 'down': 17, 'left': 15, 'up': 11, 'left_up': 4, 'left_down': 1}
# - annotator 4: classes=5 total=71
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'left': 19, 'right': 18, 'down': 17, 'left_up': 11, 'up': 6}
# - annotator 5: classes=6 total=77
#   classes: ['down', 'left', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'left': 20, 'down': 19, 'right': 17, 'up': 10, 'left_up': 8, 'right_down': 3}
#   union(7): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#
# === label/person_21_night_low_h265.json ===
# - annotator 3: classes=7 total=50
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'up']
#   counts:  {'down': 18, 'left': 15, 'right': 10, 'up': 3, 'left_up': 2, 'left_down': 1, 'right_down': 1}
# - annotator 4: classes=5 total=48
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 17, 'left': 13, 'right': 11, 'up': 5, 'left_up': 2}
# - annotator 5: classes=8 total=56
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 19, 'left': 14, 'right': 11, 'left_up': 5, 'up': 3, 'left_down': 2, 'right_down': 1, 'right_up': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_24_day_high_h265.json ===
# - annotator 3: classes=5 total=55
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 38, 'left': 8, 'up': 5, 'right': 3, 'left_down': 1}
# - annotator 4: classes=5 total=52
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 30, 'up': 8, 'left': 8, 'right': 3, 'left_down': 3}
# - annotator 5: classes=8 total=60
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#   counts:  {'down': 29, 'left': 10, 'left_down': 10, 'right': 3, 'left_up': 3, 'up': 3, 'right_up': 1, 'right_down': 1}
#   union(8): ['down', 'left', 'left_down', 'left_up', 'right', 'right_down', 'right_up', 'up']
#
# === label/person_24_day_low_h265.json ===
# - annotator 3: classes=5 total=46
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 30, 'left': 5, 'right': 5, 'up': 4, 'left_up': 2}
# - annotator 4: classes=5 total=43
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 27, 'left': 5, 'right': 5, 'up': 5, 'left_up': 1}
# - annotator 5: classes=6 total=51
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 29, 'left': 7, 'up': 6, 'right': 5, 'left_up': 2, 'left_down': 2}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_24_night_high_h265.json ===
# - annotator 3: classes=6 total=45
#   classes: ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#   counts:  {'down': 25, 'left': 7, 'right': 6, 'up': 4, 'left_up': 2, 'left_down': 1}
# - annotator 4: classes=5 total=42
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 21, 'up': 8, 'right': 6, 'left': 5, 'left_up': 2}
# - annotator 5: classes=5 total=44
#   classes: ['down', 'left', 'left_down', 'right', 'up']
#   counts:  {'down': 20, 'left': 15, 'right': 6, 'up': 2, 'left_down': 1}
#   union(6): ['down', 'left', 'left_down', 'left_up', 'right', 'up']
#
# === label/person_24_night_low_h265.json ===
# - annotator 3: classes=4 total=38
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 18, 'left': 9, 'up': 7, 'right': 4}
# - annotator 4: classes=4 total=38
#   classes: ['down', 'left', 'right', 'up']
#   counts:  {'down': 19, 'left': 8, 'up': 7, 'right': 4}
# - annotator 5: classes=5 total=35
#   classes: ['down', 'left', 'left_up', 'right', 'up']
#   counts:  {'down': 20, 'left': 9, 'right': 4, 'up': 1, 'left_up': 1}
#   union(5): ['down', 'left', 'left_up', 'right', 'up']
#
# [INFO] saved summary to per_file_annotator_label_stats.json
